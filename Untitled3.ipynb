# %% [markdown]
# <a href="https://colab.research.google.com/github/rajkamalnitj/data_analysis/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data <- read.csv("/content/CC GENERAL.csv")
# print(data)
 head(data)
# Out:
#   CUST_ID BALANCE    BALANCE_FREQUENCY PURCHASES ONEOFF_PURCHASES
# 1 C10001    40.90075 0.818182            95.40      0.00
# 2 C10002  3202.46742 0.909091             0.00      0.00
# 3 C10003  2495.14886 1.000000           773.17    773.17
# 4 C10004  1666.67054 0.636364          1499.00   1499.00
# 5 C10005   817.71434 1.000000            16.00     16.00
# 6 C10006  1809.82875 1.000000          1333.28      0.00
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY
# 1   95.40                   0.000     0.166667
# 2    0.00                6442.945     0.000000
# 3    0.00                   0.000     1.000000
# 4    0.00                 205.788     0.083333
# 5    0.00                   0.000     0.083333
# 6 1333.28                   0.000     0.666667
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY
# 1 0.000000                   0.083333
# 2 0.000000                   0.000000
# 3 1.000000                   0.000000
# 4 0.083333                   0.000000
# ...

# %%
data <- na.omit(data)
 data
# Out:
#      CUST_ID BALANCE     BALANCE_FREQUENCY PURCHASES ONEOFF_PURCHASES
# 1    C10001     40.90075 0.818182            95.40      0.00
# 2    C10002   3202.46742 0.909091             0.00      0.00
# 3    C10003   2495.14886 1.000000           773.17    773.17
# 5    C10005    817.71434 1.000000            16.00     16.00
# 6    C10006   1809.82875 1.000000          1333.28      0.00
# 7    C10007    627.26081 1.000000          7091.01   6402.63
# 8    C10008   1823.65274 1.000000           436.20      0.00
# 9    C10009   1014.92647 1.000000           861.49    661.49
# 10   C10010    152.22598 0.545455          1281.60   1281.60
# 11   C10011   1293.12494 1.000000           920.12      0.00
# 12   C10012    630.79474 0.818182          1492.18   1492.18
# 13   C10013   1516.92862 1.000000          3217.99   2500.23
# 14   C10014    921.69337 1.000000          2137.93    419.96
# 15   C10015   2772.77273 1.000000             0.00      0.00
# ...

# %%
summary(data)
# Out:
#    CUST_ID             BALANCE        BALANCE_FREQUENCY   PURCHASES
#  Length:8636        Min.   :    0.0   Min.   :0.0000    Min.   :    0.00
#  Class :character   1st Qu.:  148.1   1st Qu.:0.9091    1st Qu.:   43.37
#  Mode  :character   Median :  916.9   Median :1.0000    Median :  375.40
#                     Mean   : 1601.2   Mean   :0.8950    Mean   : 1025.43
#                     3rd Qu.: 2105.2   3rd Qu.:1.0000    3rd Qu.: 1145.98
#                     Max.   :19043.1   Max.   :1.0000    Max.   :49039.57
#  ONEOFF_PURCHASES   INSTALLMENTS_PURCHASES  CASH_ADVANCE
#  Min.   :    0.00   Min.   :    0.00       Min.   :    0.0
#  1st Qu.:    0.00   1st Qu.:    0.00       1st Qu.:    0.0
#  Median :   44.99   Median :   94.78       Median :    0.0
#  Mean   :  604.90   Mean   :  420.84       Mean   :  994.2
#  3rd Qu.:  599.10   3rd Qu.:  484.15       3rd Qu.: 1132.4
#  Max.   :40761.25   Max.   :22500.00       Max.   :47137.2
#  PURCHASES_FREQUENCY ONEOFF_PURCHASES_FREQUENCY
# ...

# %%
d <- dist(data, method = "euclidean")
d
